# %%
import pyspedas
import pytplot
from pytplot import tplot, options, store_data, data_quants, xlim

import numpy as np
import plasma_params as pp

# %%
pp.Q
np.pi
# Out:
# 3.141592653589793

# %%
tr = ['2017-04-24 14:00:00', '2017-04-24 17:00:00']
from pyspedas.erg import mgf, pwe_hfa, pwe_ofa, orb
orb(trange=tr)
mgf(trange=tr)
pwe_hfa(trange=tr, level='l3')
pwe_hfa(trange=tr, datatype='spec')
pwe_ofa(trange=tr, datatype='spec')
# Out:
# 22-Feb-24 16:06:54: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/orb/def/2017/
# 22-Feb-24 16:06:55: File is current: erg_data/satellite/erg/orb/def/2017/erg_orb_l2_20170424_v03.cdf
# 22-Feb-24 16:06:55: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/mgf/l2/8sec/2017/04/
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Level-2 orbit data
#
# Information about ERG orbit
#
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
#
# Contact: erg-sc-core at isee.nagoya-u.ac.jp
# **************************************************************************
# 22-Feb-24 16:06:56: File is current: erg_data/satellite/erg/mgf/l2/8sec/2017/04/erg_mgf_l2_8sec_20170424_v03.04.cdf
# 22-Feb-24 16:06:56: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l3/2017/04/
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Magnetic Field Experiment (MGF) Level 2 spin-averaged magnetic field data
#
# Information about ERG MGF
#
# PI:  Ayako Matsuoka
# Affiliation: Data Analysis Center for Geomagnetism and Space Magnetism, Graduate School of Science, Kyoto University, Kitashirakawa-Oiwake Cho, Sakyo-ku Kyoto 606-8502, Japan
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of MGF L2: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Mgf
# Contact: erg_mgf_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 22-Feb-24 16:06:57: File is current: erg_data/satellite/erg/pwe/hfa/l3/2017/04/erg_pwe_hfa_l3_1min_20170424_v03_07.cdf
# 22-Feb-24 16:06:57: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/hfa/l2/spec/low/2017/04/
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) High Frequency Analyzer (HFA) Level 3 UHR frequency and electron density data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara and Ayako Matsuoka
# Affiliation: Kanazawa University and Kyoto University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 22-Feb-24 16:06:57: File is current: erg_data/satellite/erg/pwe/hfa/l2/spec/low/2017/04/erg_pwe_hfa_l2_spec_low_20170424_v01_02.cdf
# 22-Feb-24 16:07:05: erg_pwe_hfa_l2_low_spectra_er contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 22-Feb-24 16:07:05: erg_pwe_hfa_l2_low_spectra_el contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 22-Feb-24 16:07:05: erg_pwe_hfa_l2_low_spectra_e_ar contains negative values; setting the z-axis to log scale will cause the negative values to be ignored on figures.
# 22-Feb-24 16:07:06: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 22-Feb-24 16:07:06: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 22-Feb-24 16:07:06: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_eu_ev
# 22-Feb-24 16:07:06: erg_pwe_hfa_l2_low_spectra_eu_ev does not contain coordinates for spectrogram plotting.  Continuing...
# 22-Feb-24 16:07:06: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 22-Feb-24 16:07:06: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 22-Feb-24 16:07:06: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_eu_bg
# 22-Feb-24 16:07:07: erg_pwe_hfa_l2_low_spectra_eu_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 22-Feb-24 16:07:07: Conflicting size for at least one dimension for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 22-Feb-24 16:07:07: Could not create coordinate v1_dim for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 22-Feb-24 16:07:07: Could not create coordinate v2_dim for variable erg_pwe_hfa_l2_low_spectra_ev_bg
# 22-Feb-24 16:07:07: erg_pwe_hfa_l2_low_spectra_ev_bg does not contain coordinates for spectrogram plotting.  Continuing...
# 22-Feb-24 16:07:07: Downloading remote index: https://ergsc.isee.nagoya-u.ac.jp/data/ergsc/satellite/erg/pwe/ofa/l2/spec/2017/04/
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Electric Field Data (HFA) Level 2 spectrum data
#
# Information about ERG PWE HFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/HFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Hfa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# 22-Feb-24 16:07:07: File is current: erg_data/satellite/erg/pwe/ofa/l2/spec/2017/04/erg_pwe_ofa_l2_spec_20170424_v02_03.cdf
#
#
# **************************************************************************
# Exploration of Energization and Radiation in Geospace (ERG) Plasma Wave Experiment (PWE) Onboard Frequency Analyzer (OFA) Level 2 spectrum data
#
# Information about ERG PWE OFA
#
# PI:  Yoshiya Kasahara
# Affiliation: Kanazawa University
#
# RoR of ERG project common: https://ergsc.isee.nagoya-u.ac.jp/data_info/rules_of_the_road.shtml.en
# RoR of PWE/OFA: https://ergsc.isee.nagoya-u.ac.jp/mw/index.php/ErgSat/Pwe/Ofa
#
# Contact: erg_pwe_info at isee.nagoya-u.ac.jp
# **************************************************************************
# ['erg_pwe_ofa_l2_spec_epoch_e132',
#  'erg_pwe_ofa_l2_spec_E_spectra_132',
#  'erg_pwe_ofa_l2_spec_quality_flag_e132',
#  'erg_pwe_ofa_l2_spec_epoch_b132',
#  'erg_pwe_ofa_l2_spec_B_spectra_132',
#  'erg_pwe_ofa_l2_spec_quality_flag_b132']

# %%
q = pp.Q
me = pp.ME
B = data_quants['erg_mgf_l2_magt_8sec']

# %%
fce = q * B * 1e-9 / (2 * np.pi * me) * 1e-3 #[kHz]
store_data('fce', data={'x': B['time'], 'y': fce})
options('fce', opt_dict = {'ylog':1, 'line_style':':', 'thick':2, 'color':'black'})
store_data('fce_01', data={'x': B['time'], 'y': fce/10})
options('fce_01', opt_dict = {'ylog':1, 'line_style':':', 'thick':2, 'color':'magenta'})

# %%
vars = pytplot.tplot_names()
# Out:
# 0 : erg_orb_l2_pos_llr
# 1 : erg_orb_l2_pos_gse
# 2 : erg_orb_l2_pos_gsm
# 3 : erg_orb_l2_pos_sm
# 4 : erg_orb_l2_pos_rmlatmlt
# 5 : erg_orb_l2_pos_eq
# 6 : erg_orb_l2_pos_iono_north
# 7 : erg_orb_l2_pos_iono_south
# 8 : erg_orb_l2_pos_blocal
# 9 : erg_orb_l2_pos_blocal_mag
# 10 : erg_orb_l2_pos_beq
# 11 : erg_orb_l2_pos_beq_mag
# 12 : erg_orb_l2_pos_Lm
# 13 : erg_orb_l2_vel_gse
# 14 : erg_orb_l2_vel_gsm
# 15 : erg_orb_l2_vel_sm
# 16 : erg_orb_l2_spn_num
# 17 : erg_orb_l2_man_prep_flag
# 18 : erg_orb_l2_man_on_flag
# 19 : erg_orb_l2_eclipse_flag
# 20 : erg_mgf_l2_epoch_8sec
# 21 : erg_mgf_l2_mag_8sec_dsi
# 22 : erg_mgf_l2_mag_8sec_gse
# 23 : erg_mgf_l2_mag_8sec_gsm
# 24 : erg_mgf_l2_mag_8sec_sm
# 25 : erg_mgf_l2_magt_8sec
# 26 : erg_mgf_l2_rmsd_8sec_dsi
# 27 : erg_mgf_l2_rmsd_8sec_gse
# 28 : erg_mgf_l2_rmsd_8sec_gsm
# 29 : erg_mgf_l2_rmsd_8sec_sm
# 30 : erg_mgf_l2_rmsd_8sec
# 31 : erg_mgf_l2_n_rmsd_8sec
# 32 : erg_mgf_l2_dyn_rng_8sec
# 33 : erg_mgf_l2_quality_8sec
# 34 : erg_mgf_l2_quality_8sec_gc
# 35 : erg_mgf_l2_igrf_8sec_dsi
# 36 : erg_mgf_l2_igrf_8sec_gse
# 37 : erg_mgf_l2_igrf_8sec_gsm
# 38 : erg_mgf_l2_igrf_8sec_sm
# 39 : erg_pwe_hfa_l3_1min_Epoch
# 40 : erg_pwe_hfa_l3_1min_Fuhr
# 41 : erg_pwe_hfa_l3_1min_ne_mgf
# 42 : erg_pwe_hfa_l3_1min_quality_flag
# 43 : erg_pwe_hfa_l2_low_Epoch
# 44 : erg_pwe_hfa_l2_low_spectra_eu
# 45 : erg_pwe_hfa_l2_low_spectra_ev
# 46 : erg_pwe_hfa_l2_low_spectra_bgamma
# 47 : erg_pwe_hfa_l2_low_spectra_esum
# 48 : erg_pwe_hfa_l2_low_spectra_er
# 49 : erg_pwe_hfa_l2_low_spectra_el
# 50 : erg_pwe_hfa_l2_low_spectra_e_mix
# 51 : erg_pwe_hfa_l2_low_spectra_e_ar
# 52 : erg_pwe_hfa_l2_low_spectra_eu_ev
# 53 : erg_pwe_hfa_l2_low_spectra_eu_bg
# 54 : erg_pwe_hfa_l2_low_spectra_ev_bg
# 55 : erg_pwe_hfa_l2_low_quality_flag
# 56 : erg_pwe_ofa_l2_spec_epoch_e132
# 57 : erg_pwe_ofa_l2_spec_E_spectra_132
# 58 : erg_pwe_ofa_l2_spec_quality_flag_e132
# 59 : erg_pwe_ofa_l2_spec_epoch_b132
# 60 : erg_pwe_ofa_l2_spec_B_spectra_132
# 61 : erg_pwe_ofa_l2_spec_quality_flag_b132
# 62 : fce
# 63 : fce_01

# %%
options('erg_pwe_hfa_l3_1min_Fuhr', opt_dict = {'thick':2, 'color':'red'})

# %%
options('erg_pwe_hfa_l2_low_spectra_e_mix', opt_dict={'yrange':[1e0, 1e1]})
store_data('hfa_fce', data = ['erg_pwe_hfa_l2_low_spectra_e_mix', 'fce', 'erg_pwe_hfa_l3_1min_Fuhr', 'erg_pwe_hfa_l2_low_spectra_e_mix'])
# Out:
# True

# %%
options('erg_pwe_ofa_l2_spec_E_spectra_132', opt_dict={'yrange':[1e0, 1e1]})
store_data('ofaE_fce', data = ['erg_pwe_ofa_l2_spec_E_spectra_132', 'fce', 'fce_01', 'erg_pwe_ofa_l2_spec_E_spectra_132'])
# Out:
# True

# %%
options('erg_pwe_ofa_l2_spec_B_spectra_132', opt_dict={'yrange':[1e0, 1e1]})
store_data('ofaB_fce', data = ['erg_pwe_ofa_l2_spec_B_spectra_132', 'fce', 'fce_01', 'erg_pwe_ofa_l2_spec_B_spectra_132'])
# Out:
# True

# %%
pytplot.timespan('2017-04-24 14:00:00', 2, 'hours')
tplot(['ofaE_fce', 'ofaB_fce'])

# %%
pytplot.timespan('2017-04-24 14:00:00', 2, 'hours')
labels = pytplot.split_vec('erg_orb_l2_pos_rmlatmlt')
pytplot.options('erg_orb_l2_pos_rmlatmlt_x', 'ytitle', 'R [Re]')
pytplot.options('erg_orb_l2_pos_rmlatmlt_y', 'ytitle', 'MLat [deg]', opt_dict={'yrange':[15, 25]})
pytplot.options('erg_orb_l2_pos_rmlatmlt_z', 'ytitle', 'MLT [h]')
tplot(['erg_orb_l2_pos_rmlatmlt_x', 'erg_orb_l2_pos_rmlatmlt_y', 'erg_orb_l2_pos_rmlatmlt_z'])
